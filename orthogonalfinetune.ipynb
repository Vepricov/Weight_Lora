# %%
from IPython.display import clear_output

# %%
# !pip install transformers peft datasets evaluate huggingface_hub trl omegaconf rouge_score --upgrade
clear_output()

# %%
from kaggle_secrets import UserSecretsClient
import os
api_keys = UserSecretsClient()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from kaggle_secrets import UserSecretsClient
#       2 import os
#       3 api_keys = UserSecretsClient()
#
# ModuleNotFoundError: No module named 'kaggle_secrets'

# %%
os.system(f'wandb login {api_keys.get_secret("wandb")}')

# %%
import os
os.system(f'huggingface-cli login --token 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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /home/shkodnik/.cache/huggingface/token
# Login successful
# 0

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.nn.functional as F

import transformers
from transformers import AutoModel, AutoTokenizer, AutoModelForSequenceClassification, AutoModelForCausalLM, AutoModelForSeq2SeqLM, BertTokenizer, BertModel 
from transformers import TrainingArguments, Trainer, Seq2SeqTrainingArguments, Seq2SeqTrainer, GenerationConfig, DataCollatorWithPadding
from transformers import pipeline
from peft import BOFTConfig, get_peft_model, LoraConfig, TaskType
from datasets import load_dataset
import evaluate
from trl import SFTConfig, SFTTrainer, DataCollatorForCompletionOnlyLM

import wandb
from omegaconf import OmegaConf

# from deepeval.benchmarks import MMLU
# from deepeval.benchmarks.tasks import MMLUTask
# from deepeval.models.base_model import DeepEvalBaseLLM

import pickle
import tqdm.notebook as tqdm

clear_output()

# %% [markdown]
# # Massive multitask language understanding (MMLU benchmark)

# %%
# Loading MMLU categories
if not os.path.exists('./categories.py'):
    # !wget https://raw.githubusercontent.com/hendrycks/test/master/categories.py

from categories import subcategories, categories as categories_inv

# %%
for subcat_name, cat_names in subcategories.items():
    subcategories[subcat_name] = cat_names[0] if isinstance(cat_names, list) else cat_names
    
categories = {}

for cat_name, subcats in categories_inv.items():
    for subcat in subcats:
        categories[subcat] = cat_name

# %%
def subcat_to_cat(subcat):
    cat_name = subcategories[subcat]
    cat_name = categories[cat_name]
    
    return cat_name

# %%
config = OmegaConf.create({
    'model_name':   'mistralai/Mistral-7B-Instruct-v0.3',
    'padding_side': 'left',
    'task_name':    'all',
    'max_length':   256,
    'n_shots': 2,
    'fp16': True,
    'bf16': False,
    'ft_strategy': 'LoRA',
    'LoRA_config': {
        'r': 16, 
        'lora_alpha': 32, 
        'lora_dropout': 0.05,
        'target_modules': ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj'],
    },
    'BOFT_config': {  # m=2, b=8
        'boft_block_size': 8,
#         'boft_block_num': 8,
        'boft_n_butterfly_factor': 1,
        'bias': 'none',
        'target_modules': ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj'],
        'boft_dropout': 0.05,
    },
    'evaluation_config':{
        'num_splits': 20,
        'max_new_tokens': 4,
        'batch_size': 1,
        'empty_cache': True,
    },
    'trainer_config': {
        'output_dir': "bogachevv/Llama-3-8b-MMLU",
        'max_seq_length': 512,
        'dataset_text_field': 'text',
        'fp16': True,
        'full_determinism': False,
        'per_device_train_batch_size': 1,
        'per_device_eval_batch_size':  1,
        'gradient_accumulation_steps': 8,
        'lr_scheduler_type': 'cosine_with_restarts',
        'lr_scheduler_kwargs':{
            'num_cycles': 6,
        },
        'warmup_steps': 100,
#         'num_train_epochs': 2,
        'learning_rate': 1e-4,
        'max_steps': 2048,
        'weight_decay': 0.01,
#         'warmup_ratio': 1e-2,
        'dataloader_num_workers': 2,
        'eval_strategy': "steps",
#         'torch_empty_cache_steps': 16,
        'eval_steps': 16,
        'logging_steps': 16,
        'load_best_model_at_end': True,
        'seed': 42,
        'data_seed': 42,
        'report_to': 'wandb',
#         'predict_with_generate': True,
#         'push_to_hub': True,
#         'hub_model_id': 'LLama-LoRA-test',
#         'hub_strategy': 'checkpoint',
#         'save_strategy': "steps",
        'save_steps': 128,
    },
})

# %%
type(config)
# Out:
# omegaconf.dictconfig.DictConfig

# %%
from pipelines import utils
device = utils.set_device(2)
# Out:
# There are 8 GPU(s) available.
# We will use the GPU: NVIDIA A100-SXM4-80GB

# %%
tokenizer = AutoTokenizer.from_pretrained(
    config.model_name, 
    padding_side=config.padding_side,
#     model_max_length=512,
    device_map=device
)
tokenizer.pad_token = tokenizer.eos_token
EOS_TOKEN = tokenizer.eos_token

mmlu_dataset =  load_dataset("cais/mmlu", config.task_name)

# %%
# Try block for clear_output() call iff succes
try:
    few_shot_datasets = {
        subject: mmlu_dataset['dev'].filter(lambda row: row['subject'] == subject)
        for subject in set(mmlu_dataset['dev']['subject'])
    }
    
    clear_output()
    print('Succes')
except:
    raise
# Out:
# Succes

# %%
def prepare_question(examples):
    prompt = f"{examples['question']}\n"
    for letter, choice in zip(('A', 'B', 'C', 'D'), examples['choices']):
        prompt += f"{letter}. {choice}\n"

    answer = chr(65 + examples['answer'])
    
    return prompt, answer

def prepare_prompt(examples, dev_dataset = None):
    if dev_dataset:
        yield from map(prepare_question, dev_dataset)
    
    yield prepare_question(examples)

# %%
def prepare_instruction_text(example):
    instructions = [
        {"role": "system", "content": f"The following are multiple choice questions (with answers) about {example['subject']}. Output 'A', 'B', 'C', or 'D'. Full answer not needed."},
    ]

    if config['n_shots'] and example['subject']:
        few_shot_dataset = few_shot_datasets[example['subject']]
        few_shot_dataset = few_shot_dataset.select(range(config['n_shots']))
    else:
        few_shot_dataset = None
    
    for prompt, ans in prepare_prompt(example, dev_dataset=few_shot_dataset):
        instructions.append({"role": "user", "content": prompt})
        instructions.append({"role": "assistant", "content": ans})
    
    text = tokenizer.apply_chat_template(
        instructions,
        tokenize=False
    )
    
    return {'text': text}

# %%
def r_replace(line, old, new):
    return line[::-1].replace(old[::-1], new[::-1], 1)[::-1]

def remove_answer(example):
    text_wa_answer = example['text']
    text_wa_answer = text_wa_answer.rsplit('<|eot_id|>', 1)[0][:-1]
    
    # for letter in ('A', 'B', 'C', 'D'):
        # text_wa_answer = text_wa_answer.replace(f'<|start_header_id|>assistant<|end_header_id|>\n\n{letter}<|eot_id|>', '<|start_header_id|>assistant<|end_header_id|>\n\n')
        # text_wa_answer = r_replace(text_wa_answer, f'<|start_header_id|>assistant<|end_header_id|>\n\n{letter}<|eot_id|>', '<|start_header_id|>assistant<|end_header_id|>\n\n')
    
    return {'text_wa_answer': text_wa_answer}

# %%
instructions_datasets = mmlu_dataset.map(prepare_instruction_text, batched=False, num_proc=2)
instructions_datasets['validation'] = instructions_datasets['validation'].map(remove_answer, batched=False)
instructions_datasets['test'] = instructions_datasets['test'].map(remove_answer, batched=False)

instructions_datasets.set_format("torch")

instructions_datasets
# Out:
# Map (num_proc=2): 100%|██████████| 14042/14042 [00:09<00:00, 1415.16 examples/s]
# Map (num_proc=2): 100%|██████████| 1531/1531 [00:01<00:00, 1225.04 examples/s]
# Map (num_proc=2): 100%|██████████| 285/285 [00:00<00:00, 735.33 examples/s]
# Map (num_proc=2): 100%|██████████| 99842/99842 [00:11<00:00, 9037.77 examples/s]
# Map: 100%|██████████| 1531/1531 [00:00<00:00, 11938.79 examples/s]
# Map: 100%|██████████| 14042/14042 [00:01<00:00, 13648.69 examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['question', 'subject', 'choices', 'answer', 'text', 'text_wa_answer'],
#         num_rows: 14042
#     })
#     validation: Dataset({
#         features: ['question', 'subject', 'choices', 'answer', 'text', 'text_wa_answer'],
#         num_rows: 1531
#     })
#     dev: Dataset({
#         features: ['question', 'subject', 'choices', 'answer', 'text'],
#         num_rows: 285
#     })
#     auxiliary_train: Dataset({
#         features: ['question', 'subject', 'choices', 'answer', 'text'],
#         num_rows: 99842
#     })
# })

# %%
print(instructions_datasets['validation'][1]['text'])
# Out:
# <s>[INST] Find all c in Z_3 such that Z_3[x]/(x^2 + c) is a field.
# A. 0
# B. 1
# C. 2
# D. 3
# [/INST] B</s>[INST] Statement 1 | If aH is an element of a factor group, then |aH| divides |a|. Statement 2 | If H and K are subgroups of G then HK is a subgroup of G.
# A. True, True
# B. False, False
# C. True, False
# D. False, True
# [/INST] B</s>[INST] Find the order of the factor group Z_6/<3>.
# A. 2
# B. 3
# C. 6
# D. 12
# [/INST] B</s>

# %%
print(instructions_datasets['validation'][1]['text_wa_answer'])
# Out:
# <s>[INST] Find all c in Z_3 such that Z_3[x]/(x^2 + c) is a field.
# A. 0
# B. 1
# C. 2
# D. 3
# [/INST] B</s>[INST] Statement 1 | If aH is an element of a factor group, then |aH| divides |a|. Statement 2 | If H and K are subgroups of G then HK is a subgroup of G.
# A. True, True
# B. False, False
# C. True, False
# D. False, True
# [/INST] B</s>[INST] Find the order of the factor group Z_6/<3>.
# A. 2
# B. 3
# C. 6
# D. 12
# [/INST] B</s

# %%
# Accessing the train, validation, and test splits
validation_dataset = instructions_datasets["validation"]
test_dataset = instructions_datasets["test"]
dev_dataset = instructions_datasets["dev"]  # dataset for few shot
auxiliary_train_dataset  = instructions_datasets['auxiliary_train']

# Check the size of each split
print(f"Validation dataset size: {len(validation_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
print(f"Dev dataset size: {len(dev_dataset)}")
print(f"Auxiliary train dataset size: {len(auxiliary_train_dataset)}")
# Out:
# Validation dataset size: 1531
# Test dataset size: 14042
# Dev dataset size: 285
# Auxiliary train dataset size: 99842

# %%
test_dataset
# Out:
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text', 'text_wa_answer'],
#     num_rows: 14042
# })

# %%
model = AutoModelForCausalLM.from_pretrained(
    config.model_name,
    device_map=device,
    torch_dtype=torch.float16,
)
# Out:
# Loading checkpoint shards: 100%|██████████| 3/3 [00:36<00:00, 12.14s/it]

# %%
accuracy_metric = evaluate.load("accuracy")

def process_prediction(pred):
    pred = pred['generated_text']
    
    pred = pred.strip().upper()
    
    pred = pred[0] if pred else 'I'
    pred = pred if pred in {'A', 'B', 'C', 'D'} else 'I'
    
    return pred

def compute_accuracy(model_preds, labels):   
    model_preds = list(map(process_prediction, model_preds))
    
    model_preds  = torch.LongTensor(list(map(ord, model_preds)))
    actual_labels = ord('A') + labels
    incorrect_labels = actual_labels.new_full(actual_labels.shape, ord('I'))
    
#     print(f"{model_preds=}\n{actual_labels=}\n{incorrect_labels=}")
    
    acc_res = accuracy_metric.compute(predictions=model_preds, references=actual_labels)['accuracy']
    corr_res = 1.0 - accuracy_metric.compute(predictions=model_preds, references=incorrect_labels)['accuracy']
    
    return {'accuracy': acc_res, 'correctness': corr_res}

# %%
model.model.layers[0].self_attn.q_proj.weight.shape[0]
# Out:
# 4096

# %%
# adapter_config = BOFTConfig(
#     task_type=TaskType.CAUSAL_LM,
#     inference_mode=False,
#     boft_block_size=8,
# #     boft_block_num=16,
#     boft_n_butterfly_factor=2,
#     bias='none',
# )

# adapter_config

# model_adapter = get_peft_model(model, adapter_config)

# %%
# model_adapter.print_trainable_parameters()

# %%
# model_adapter

# %%
adapter_config = BOFTConfig(
        task_type=TaskType.CAUSAL_LM,
        inference_mode=False,
        **OmegaConf.to_object(config.BOFT_config)
    )

model_adapter = get_peft_model(model, adapter_config)

# %%
if config.ft_strategy == 'LoRA':
    adapter_config = LoraConfig(
        task_type=TaskType.CAUSAL_LM,
        inference_mode=False, 
        **OmegaConf.to_object(config.LoRA_config),
    )
elif config.ft_strategy == 'BOFT':
    adapter_config = BOFTConfig(
        task_type=TaskType.CAUSAL_LM,
        inference_mode=False,
        **OmegaConf.to_object(config.BOFT_config)
    )
else:
    raise ValueError('Incorrect FT type')

model_adapter = get_peft_model(model, adapter_config)    
model_adapter.print_trainable_parameters()
# Out:
# Using /home/shkodnik/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Creating extension directory /home/shkodnik/.cache/torch_extensions/py311_cu121/fbd_cuda...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/shkodnik/.cache/torch_extensions/py311_cu121/fbd_cuda/build.ninja...
# Building extension module fbd_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] gcc -MMD -MF fbd_cuda.o.d -DTORCH_EXTENSION_NAME=fbd_cuda -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include -isystem /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/TH -isystem /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /home/shkodnik/anaconda3/envs/python3.11.7/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -c /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda.cpp -o fbd_cuda.o
# [2/3] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output fbd_cuda_kernel.cuda.o.d -ccbin gcc -DTORCH_EXTENSION_NAME=fbd_cuda -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include -isystem /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/TH -isystem /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /home/shkodnik/anaconda3/envs/python3.11.7/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_75,code=sm_75 -gencode=arch=compute_80,code=compute_80 -gencode=arch=compute_80,code=sm_80 --compiler-options '-fPIC' -std=c++17 -c /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu -o fbd_cuda_kernel.cuda.o
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu: In lambda function:
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:66:133: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    66 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(input.type(), "forward_fast_block_diag1", ([&] {
#       |                                                                                                                                     ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:66:160: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    66 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(input.type(), "forward_fast_block_diag1", ([&] {
#       |                                                                                                                                                                ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu: In lambda function:
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:66:131: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    66 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(input.type(), "forward_fast_block_diag1", ([&] {
#       |                                                                                                                                   ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:66:157: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    66 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(input.type(), "forward_fast_block_diag1", ([&] {
#       |                                                                                                                                                             ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu: In lambda function:
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:66:139: warning: ‘T* at::Tensor::data() const [with T = c10::Half]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    66 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(input.type(), "forward_fast_block_diag1", ([&] {
#       |                                                                                                                                           ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:66:169: warning: ‘T* at::Tensor::data() const [with T = c10::Half]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    66 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(input.type(), "forward_fast_block_diag1", ([&] {
#       |                                                                                                                                                                         ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu: In lambda function:
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:97:140: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    97 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(grad_output.type(), "backward_fast_block_diag", ([&] {
#       |                                                                                                                                            ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:97:171: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    97 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(grad_output.type(), "backward_fast_block_diag", ([&] {
#       |                                                                                                                                                                           ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu: In lambda function:
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:97:138: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    97 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(grad_output.type(), "backward_fast_block_diag", ([&] {
#       |                                                                                                                                          ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:97:168: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    97 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(grad_output.type(), "backward_fast_block_diag", ([&] {
#       |                                                                                                                                                                        ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu: In lambda function:
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:97:146: warning: ‘T* at::Tensor::data() const [with T = c10::Half]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    97 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(grad_output.type(), "backward_fast_block_diag", ([&] {
#       |                                                                                                                                                  ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/peft/tuners/boft/fbd/fbd_cuda_kernel.cu:97:180: warning: ‘T* at::Tensor::data() const [with T = c10::Half]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    97 |     AT_DISPATCH_FLOATING_TYPES_AND_HALF(grad_output.type(), "backward_fast_block_diag", ([&] {
#       |                                                                                                                                                                                    ^
# /home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# [3/3] gcc fbd_cuda.o fbd_cuda_kernel.cuda.o -shared -L/home/shkodnik/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o fbd_cuda.so
# Loading extension module fbd_cuda...
# trainable params: 11,337,728 || all params: 7,259,361,280 || trainable%: 0.1562

# %%
model.eval()

pl = pipeline(
    "text-generation",
    model=model,       # WARNING: model used insted of lora_model
    tokenizer=tokenizer,
    torch_dtype=torch.float16
)

# %%
# %%time

model_preds = []

with torch.no_grad():
    for i, split in enumerate(np.array_split(np.arange(len(test_dataset)), 20)):
        print(f"Start iteration {i}")
        print(f"\tstart pos: {np.min(split)}\tend pos: {np.max(split)}")
        
        model_pred = pl(
            test_dataset.select(split)['text_wa_answer'],
    #         validation_dataset.shuffle(42).select(range(512))['text_wa_answer'],
    #         validation_dataset['text_wa_answer'],
            return_full_text=False,
            max_new_tokens=4,
            do_sample=False,
            temperature=None,
            top_p=None,
            batch_size=1
        )
        model_preds += model_pred
        torch.cuda.empty_cache()
        
        print(f"Finish iteration {i}")
        print(f"\t{len(model_preds)=}")

model_preds_merged = []
for ls in model_preds:
    model_preds_merged += ls

model_preds = model_preds_merged

# model_preds
# Out:
# Start iteration 0
# 	start pos: 0	end pos: 702
# Finish iteration 0
# 	len(model_preds)=703
# Start iteration 1
# 	start pos: 703	end pos: 1405
# Finish iteration 1
# 	len(model_preds)=1406
# Start iteration 2
# 	start pos: 1406	end pos: 2107
# Finish iteration 2
# 	len(model_preds)=2108
# Start iteration 3
# 	start pos: 2108	end pos: 2809
# Finish iteration 3
# 	len(model_preds)=2810
# Start iteration 4
# 	start pos: 2810	end pos: 3511
# Finish iteration 4
# 	len(model_preds)=3512
# Start iteration 5
# 	start pos: 3512	end pos: 4213
# Finish iteration 5
# 	len(model_preds)=4214
# Start iteration 6
# 	start pos: 4214	end pos: 4915
# Finish iteration 6
# 	len(model_preds)=4916
# Start iteration 7
# 	start pos: 4916	end pos: 5617
# Finish iteration 7
# 	len(model_preds)=5618
# Start iteration 8
# 	start pos: 5618	end pos: 6319
# Finish iteration 8
# 	len(model_preds)=6320
# Start iteration 9
# 	start pos: 6320	end pos: 7021
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Finish iteration 9
# 	len(model_preds)=7022
# Start iteration 10
# 	start pos: 7022	end pos: 7723
# Finish iteration 10
# 	len(model_preds)=7724
# Start iteration 11
# 	start pos: 7724	end pos: 8425
# Finish iteration 11
# 	len(model_preds)=8426
# Start iteration 12
# 	start pos: 8426	end pos: 9127
# Finish iteration 12
# 	len(model_preds)=9128
# Start iteration 13
# 	start pos: 9128	end pos: 9829
# Finish iteration 13
# 	len(model_preds)=9830
# Start iteration 14
# 	start pos: 9830	end pos: 10531
# Finish iteration 14
# 	len(model_preds)=10532
# Start iteration 15
# 	start pos: 10532	end pos: 11233
# Finish iteration 15
# 	len(model_preds)=11234
# Start iteration 16
# 	start pos: 11234	end pos: 11935
# Finish iteration 16
# 	len(model_preds)=11936
# Start iteration 17
# 	start pos: 11936	end pos: 12637
# Finish iteration 17
# 	len(model_preds)=12638
# Start iteration 18
# 	start pos: 12638	end pos: 13339
# Finish iteration 18
# 	len(model_preds)=13340
# Start iteration 19
# 	start pos: 13340	end pos: 14041
# Finish iteration 19
# 	len(model_preds)=14042
# CPU times: user 34min 26s, sys: 3min 56s, total: 38min 23s
# Wall time: 38min 25s

# %%
for i in range(len(model_preds)):
    model_preds[i]['subject'] = test_dataset[i]['subject']
    
model_preds
# Out:
# [{'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '2>\n\n', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '> The zero element', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nG', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nIn', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nIn', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nIn', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nTo', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nFind', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nA', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nA', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\n(', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nUsing', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nA', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nFor', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nIn', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nA', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nStatement', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nIn', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nThe', 'subject': 'abstract_algebra'},
#  {'generated_text': '>', 'subject': 'abstract_algebra'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nD', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nYou', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nProp', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '> The mental sym', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nG', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nD', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nB', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nD', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nComplete', 'subject': 'anatomy'},
#  {'generated_text': '> The auditory', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '> The coronal', 'subject': 'anatomy'},
#  {'generated_text': '>hyoid bone', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nB', 'subject': 'anatomy'},
#  {'generated_text': '> The infra', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nC', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nYou', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nC', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nIn', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nIn', 'subject': 'anatomy'},
#  {'generated_text': '> The digastr', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nC', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '> The walls of', 'subject': 'anatomy'},
#  {'generated_text': '> The zyg', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nD', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nPar', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nMac', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nB', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nIn', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nProp', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nAn', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nD', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nPar', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nA', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nSal', 'subject': 'anatomy'},
#  {'generated_text': '> During swallowing', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>', 'subject': 'anatomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nIf', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nYou', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nB', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nE', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nOn', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nM', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nTo', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nM', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nV', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nPlan', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nSupp', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nC', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nJ', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nCor', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nAcc', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nAss', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nLife', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nJ', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nTo', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWithout', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nPlan', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhen', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nC', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nYou', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\nA fusion', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nTo', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nIf', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nAss', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nHow', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nOur', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nPl', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nB', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nIf', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nMo', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nTo', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nC', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nAss', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nIo', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nAss', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nGreen', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nTo', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nSun', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhere', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhen', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nM', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThere', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nAss', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nAppro', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nAss', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhich', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nA', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nC', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nWhat', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nD', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nHow', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nThe', 'subject': 'astronomy'},
#  {'generated_text': '>', 'subject': 'astronomy'},
#  {'generated_text': '>\n\nC', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nC', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nC', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nIn', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nAl', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nWhat', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nC', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nFl', 'subject': 'business_ethics'},
#  {'generated_text': '> Disclosure,', 'subject': 'business_ethics'},
#  {'generated_text': '> A corporation is', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nWhen', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '> To make a', 'subject': 'business_ethics'},
#  {'generated_text': '> That it is', 'subject': 'business_ethics'},
#  {'generated_text': '>', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nNorm', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nPro', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nBet', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nB', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nCor', 'subject': 'business_ethics'},
#  {'generated_text': '> Environmental management systems',
#   'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nE', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nIn', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nPred', 'subject': 'business_ethics'},
#  {'generated_text': '>\nThere are', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nA', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nSmall', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nA', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nAl', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nWhen', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nC', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nAcc', 'subject': 'business_ethics'},
#  {'generated_text': '>\nAffirm', 'subject': 'business_ethics'},
#  {'generated_text': '> Caveat', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nAcc', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nCor', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '> Denial of', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nGlobal', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nIn', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nMan', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '> The Social Account', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nC', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nIns', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThere', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nPost', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nA', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nIn', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nCon', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nAcc', 'subject': 'business_ethics'},
#  {'generated_text': '>\nBusiness', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nS', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nF', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nB', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nCor', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nAcc', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nThe', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nIn', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nD', 'subject': 'business_ethics'},
#  {'generated_text': '>\nBusiness', 'subject': 'business_ethics'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nS', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nC', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nMus', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nG', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nK', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nColl', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nEmb', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nTo', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nHow', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nG', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nHow', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nImp', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nRem', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhen', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nMus', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPre', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAss', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nH', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nTo', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAss', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nW', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAss', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhen', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIns', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIf', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhen', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPal', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIf', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nHow', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nHy', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAdd', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhere', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIns', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nEx', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWho', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPre', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAfter', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAss', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nMut', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhen', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPar', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAss', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nB', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIV', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nFor', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAss', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nMet', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAss', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nUnder', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nSelect', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nFast', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPro', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAs', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nUnder', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWho', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nEnd', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nDi', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nHa', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nR', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nD', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPh', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nProp', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nOne', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nTo', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nC', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhich', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPh', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nO', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhy', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nAn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nGl', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nO', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nMe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhen', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhy', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhen', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhy', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nA', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nIn', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nWhat', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nPh', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nThe', 'subject': 'clinical_knowledge'},
#  {'generated_text': '>\n\nBased', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nPh', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nWhen', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nTarget', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nCor', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nTrans', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nCell', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nAcc', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nPl', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nTh', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nAll', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nO', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nL', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nX', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIm', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nAn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nAir', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nCor', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIf', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nE', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nM', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nAm', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nPh', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nHard', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nWhich', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nWhich', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nAnt', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nMar', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nA', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nAn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nMut', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nRoot', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nCor', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nC', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nB', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nM', 'subject': 'college_biology'},
#  {'generated_text': '>\nD.', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nChar', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nD', 'subject': 'college_biology'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nWhen', 'subject': 'college_chemistry'},
#  {'generated_text': '> The equation ', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nA', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\nC.', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nC', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nPro', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nA', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nA', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nFor', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nT', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nN', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nCH', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nWhen', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nFirst', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nG', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '> It has little', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nCr', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nA', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nRed', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nS', 'subject': 'college_chemistry'},
#  {'generated_text': '>\n\nThe', 'subject': 'college_computer_science'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_computer_science'},
#  {'generated_text': '>\n\nIn', 'subject': 'college_computer_science'},
#  {'generated_text': '>\n\nTo', 'subject': 'college_computer_science'},
#  ...]

# %%
with open('./fs_preds.bin', 'wb') as f:
    pickle.dump(
        obj=(model_preds, test_dataset['answer']),
        file=f
    )

# %%
preds_df = pd.DataFrame(model_preds)

preds_df['pred'] = preds_df.apply(process_prediction, axis=1)
preds_df['true'] = list(map(lambda v: chr(v + ord('A')), test_dataset['answer']))
preds_df['corr'] = (preds_df['pred'] == preds_df['true']).astype(np.int32)
preds_df['category'] = preds_df['subject'].apply(subcat_to_cat)

preds_df.head(20)
# Out:
#         generated_text           subject pred true  corr category
# 0             >\n\nThe  abstract_algebra    I    B     0     STEM
# 1               2>\n\n  abstract_algebra    I    C     0     STEM
# 2              >\n\nTo  abstract_algebra    I    D     0     STEM
# 3                    >  abstract_algebra    I    B     0     STEM
# 4              >\n\nTo  abstract_algebra    I    B     0     STEM
# 5       >\n\nStatement  abstract_algebra    I    A     0     STEM
# 6       >\n\nStatement  abstract_algebra    I    A     0     STEM
# 7       >\n\nStatement  abstract_algebra    I    D     0     STEM
# 8             >\n\nThe  abstract_algebra    I    B     0     STEM
# 9              >\n\nTo  abstract_algebra    I    C     0     STEM
# 10      >\n\nStatement  abstract_algebra    I    C     0     STEM
# 11                   >  abstract_algebra    I    C     0     STEM
# 12            >\n\nThe  abstract_algebra    I    A     0     STEM
# 13             >\n\nTo  abstract_algebra    I    C     0     STEM
# 14            >\n\nThe  abstract_algebra    I    C     0     STEM
# 15                   >  abstract_algebra    I    B     0     STEM
# 16                   >  abstract_algebra    I    C     0     STEM
# 17             >\n\nTo  abstract_algebra    I    C     0     STEM
# 18  > The zero element  abstract_algebra    I    D     0     STEM
# 19                   >  abstract_algebra    I    A     0     STEM

# %%
preds_df[['subject', 'corr']].groupby(['subject']).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 preds_df[['subject', 'corr']].groupby(['subject']).mean()
#
# NameError: name 'preds_df' is not defined

# %%
preds_df[['category', 'corr']].groupby(['category']).mean()
# Out:
#                                      corr
# category
# STEM                             0.000000
# humanities                       0.000000
# other (business, health, misc.)  0.000308
# social sciences                  0.000000

# %%
compute_accuracy(model_preds, test_dataset['answer'])
# Out:
# {'accuracy': 7.121492664862555e-05, 'correctness': 7.121492664863283e-05}

# %%
assert False

# %%
training_args = SFTConfig(
    **OmegaConf.to_object(config.trainer_config),
)

# %%
trainer = SFTTrainer(
    model=model_adapter,
    args=training_args,
#     args=SFTConfig(
#         output_dir="/tmp",
#         per_device_train_batch_size=1,
#         per_device_eval_batch_size=2,
#         fp16=True,
#     ),
    train_dataset=auxiliary_train_dataset,
    eval_dataset=validation_dataset.shuffle(42).select(range(64)),
#     formatting_func=formatting_prompts_func,
#     data_collator=collator,
     compute_metrics=compute_accuracy,
)
# Out:
# Map:  19%|█▉        | 19000/99842 [00:18<01:20, 1007.99 examples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 trainer = SFTTrainer(
#       2     model=model_adapter,
#       3     args=training_args,
#       4 #     args=SFTConfig(
#       5 #         output_dir="/tmp",
#       6 #         per_device_train_batch_size=1,
#       7 #         per_device_eval_batch_size=2,
#       8 #         fp16=True,
#       9 #     ),
#      10     train_dataset=auxiliary_train_dataset,
#      11     eval_dataset=validation_dataset.shuffle(42).select(range(64)),
#      12 #     formatting_func=formatting_prompts_func,
#      13 #     data_collator=collator,
#      14      compute_metrics=compute_accuracy,
#      15 )
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:361, in SFTTrainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics, peft_config, dataset_text_field, packing, formatting_func, max_seq_length, infinite, num_of_sequences, chars_per_token, dataset_num_proc, dataset_batch_size, neftune_noise_alpha, model_init_kwargs, dataset_kwargs, eval_packing)
#     359 with PartialState().local_main_process_first():
#     360     if train_dataset is not None:
# --> 361         train_dataset = self._prepare_dataset(
#     362             train_dataset,
#     363             tokenizer,
#     364             args.packing,
#     365             args.dataset_text_field,
#     366             args.max_seq_length,
#     367             formatting_func,
#     368             args.num_of_sequences,
#     369             args.chars_per_token,
#     370             remove_unused_columns=args.remove_unused_columns if args is not None else True,
#     371             **args.dataset_kwargs,
#     372         )
#     373     if eval_dataset is not None:
#     374         _multiple = isinstance(eval_dataset, dict)
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:514, in SFTTrainer._prepare_dataset(self, dataset, tokenizer, packing, dataset_text_field, max_seq_length, formatting_func, num_of_sequences, chars_per_token, remove_unused_columns, append_concat_token, add_special_tokens, skip_prepare_dataset)
#     508     raise ValueError(
#     509         "You need to provide either `dataset_text_field` or `formatting_func` argument. Alternatively, you "
#     510         "can skip the dataset preparation by using `SFTConfig(dataset_kwargs={'skip_prepare_dataset': True})`."
#     511     )
#     513 if not packing:
# --> 514     return self._prepare_non_packed_dataloader(
#     515         tokenizer,
#     516         dataset,
#     517         dataset_text_field,
#     518         max_seq_length,
#     519         formatting_func,
#     520         add_special_tokens,
#     521         remove_unused_columns,
#     522     )
#     524 else:
#     525     return self._prepare_packed_dataloader(
#     526         tokenizer,
#     527         dataset,
#    (...)
#     534         add_special_tokens,
#     535     )
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:588, in SFTTrainer._prepare_non_packed_dataloader(self, tokenizer, dataset, dataset_text_field, max_seq_length, formatting_func, add_special_tokens, remove_unused_columns)
#     586 if isinstance(dataset, datasets.Dataset):
#     587     map_kwargs["num_proc"] = self.dataset_num_proc  # this arg is not available for IterableDataset
# --> 588 tokenized_dataset = dataset.map(tokenize, **map_kwargs)
#     590 return tokenized_dataset
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/datasets/arrow_dataset.py:602, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     600     self: "Dataset" = kwargs.pop("self")
#     601 # apply actual function
# --> 602 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     603 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     604 for dataset in datasets:
#     605     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/datasets/arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/datasets/arrow_dataset.py:3156, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3150 if transformed_dataset is None:
#    3151     with hf_tqdm(
#    3152         unit=" examples",
#    3153         total=pbar_total,
#    3154         desc=desc or "Map",
#    3155     ) as pbar:
# -> 3156         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3157             if done:
#    3158                 shards_done += 1
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/datasets/arrow_dataset.py:3547, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3543 indices = list(
#    3544     range(*(slice(i, i + batch_size).indices(shard.num_rows)))
#    3545 )  # Something simpler?
#    3546 try:
# -> 3547     batch = apply_function_on_filtered_inputs(
#    3548         batch,
#    3549         indices,
#    3550         check_same_num_examples=len(shard.list_indexes()) > 0,
#    3551         offset=offset,
#    3552     )
#    3553 except NumExamplesMismatchError:
#    3554     raise DatasetTransformationNotAllowedError(
#    3555         "Using `.map` in batched mode on a dataset with attached indexes is allowed only if it doesn't create or remove existing examples. You can first run `.drop_index() to remove your index and then re-add it."
#    3556     ) from None
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/datasets/arrow_dataset.py:3416, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3414 if with_rank:
#    3415     additional_args += (rank,)
# -> 3416 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3417 if isinstance(processed_inputs, LazyDict):
#    3418     processed_inputs = {
#    3419         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3420     }
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:551, in SFTTrainer._prepare_non_packed_dataloader.<locals>.tokenize(element)
#     550 def tokenize(element):
# --> 551     outputs = tokenizer(
#     552         element[dataset_text_field] if not use_formatting_func else formatting_func(element),
#     553         add_special_tokens=add_special_tokens,
#     554         truncation=True,
#     555         padding=False,
#     556         max_length=max_seq_length,
#     557         return_overflowing_tokens=False,
#     558         return_length=False,
#     559     )
#     561     if use_formatting_func and not isinstance(formatting_func(element), list):
#     562         raise ValueError(
#     563             "The `formatting_func` should return a list of processed strings since it can lead to silent bugs."
#     564         )
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:3055, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3053     if not self._in_target_context_manager:
#    3054         self._switch_to_input_mode()
# -> 3055     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    3056 if text_target is not None:
#    3057     self._switch_to_target_mode()
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:3142, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3137         raise ValueError(
#    3138             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    3139             f" {len(text_pair)}."
#    3140         )
#    3141     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 3142     return self.batch_encode_plus(
#    3143         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3144         add_special_tokens=add_special_tokens,
#    3145         padding=padding,
#    3146         truncation=truncation,
#    3147         max_length=max_length,
#    3148         stride=stride,
#    3149         is_split_into_words=is_split_into_words,
#    3150         pad_to_multiple_of=pad_to_multiple_of,
#    3151         return_tensors=return_tensors,
#    3152         return_token_type_ids=return_token_type_ids,
#    3153         return_attention_mask=return_attention_mask,
#    3154         return_overflowing_tokens=return_overflowing_tokens,
#    3155         return_special_tokens_mask=return_special_tokens_mask,
#    3156         return_offsets_mapping=return_offsets_mapping,
#    3157         return_length=return_length,
#    3158         verbose=verbose,
#    3159         split_special_tokens=split_special_tokens,
#    3160         **kwargs,
#    3161     )
#    3162 else:
#    3163     return self.encode_plus(
#    3164         text=text,
#    3165         text_pair=text_pair,
#    (...)
#    3182         **kwargs,
#    3183     )
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:3338, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3328 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3329 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3330     padding=padding,
#    3331     truncation=truncation,
#    (...)
#    3335     **kwargs,
#    3336 )
# -> 3338 return self._batch_encode_plus(
#    3339     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3340     add_special_tokens=add_special_tokens,
#    3341     padding_strategy=padding_strategy,
#    3342     truncation_strategy=truncation_strategy,
#    3343     max_length=max_length,
#    3344     stride=stride,
#    3345     is_split_into_words=is_split_into_words,
#    3346     pad_to_multiple_of=pad_to_multiple_of,
#    3347     return_tensors=return_tensors,
#    3348     return_token_type_ids=return_token_type_ids,
#    3349     return_attention_mask=return_attention_mask,
#    3350     return_overflowing_tokens=return_overflowing_tokens,
#    3351     return_special_tokens_mask=return_special_tokens_mask,
#    3352     return_offsets_mapping=return_offsets_mapping,
#    3353     return_length=return_length,
#    3354     verbose=verbose,
#    3355     split_special_tokens=split_special_tokens,
#    3356     **kwargs,
#    3357 )
#
# File ~/Sber_Lora/ShkodnikVenv/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:528, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     525 if self._tokenizer.encode_special_tokens != split_special_tokens:
#     526     self._tokenizer.encode_special_tokens = split_special_tokens
# --> 528 encodings = self._tokenizer.encode_batch(
#     529     batch_text_or_text_pairs,
#     530     add_special_tokens=add_special_tokens,
#     531     is_pretokenized=is_split_into_words,
#     532 )
#     534 # Convert encoding to dict
#     535 # `Tokens` has type: Tuple[
#     536 #                       List[Dict[str, List[List[int]]]] or List[Dict[str, 2D-Tensor]],
#     537 #                       List[EncodingFast]
#     538 #                    ]
#     539 # with nested dimensions corresponding to batch, overflows, sequence length
#     540 tokens_and_encodings = [
#     541     self._convert_encoding(
#     542         encoding=encoding,
#    (...)
#     551     for encoding in encodings
#     552 ]
#
# KeyboardInterrupt:

# %%
# tokenizer.decode(trainer.train_dataset[0]['input_ids'])

# %%
# for batch in trainer.get_train_dataloader():
#     print(tokenizer.batch_decode(batch['input_ids']))
#     break

# %%
torch.cuda.empty_cache()

trainer.train()

# %%
# torch.cuda.empty_cache()

# %%
pl = pipeline(
    "text-generation",
    model=lora_model,
    tokenizer=tokenizer,
)

# %%
# %%time

model_preds = pl(
    validation_dataset.shuffle(42).select(range(512))['text_wa_answer'],
#     validation_dataset['text_wa_answer'],
    return_full_text=False,
    max_new_tokens=16,
    do_sample=False,
    temperature=None,
    top_p=None,
    batch_size=4,
)
torch.cuda.empty_cache()

model_preds_merged = []
for ls in model_preds:
    model_preds_merged += ls

model_preds = model_preds_merged

# model_preds

# %%
for i in range(len(model_preds)):
    model_preds[i]['subject'] = validation_dataset[i]['subject']
    
model_preds

# %%
compute_accuracy(model_preds, validation_dataset.select(range(len(model_preds)))['answer'])

# %%
lora_model.save_pretrained("./fine_tuned_model")
tokenizer.save_pretrained("./fine_tuned_model")

# %%
# !zip fine_tuned_model.zip ./fine_tuned_model/*
